# %% [markdown]
# # Seeing Data — notebook lab
#
# **Core question:** How do charts create meaning?
#
# This lab uses Anscombe’s quartet to separate summary, visual evidence and interpretation. You may use Copilot, but you must predict, constrain, verify and explain its contribution.

# %% [markdown]
# ## Learning record
#
# Before writing code, complete these statements:
#
# - I expect four datasets with the same summary statistics to look …
# - A visual pattern is not automatically an insight because …
# - If I use Copilot, I will verify its work by …

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.precision', 3)

# %% [markdown]
# ## Load the evidence
#
# The values below are Anscombe’s quartet. Keeping them inside the notebook makes the activity work without internet access.

# %%
x_common = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
x_four = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
values = {
    'A': (x_common, [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]),
    'B': (x_common, [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]),
    'C': (x_common, [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]),
    'D': (x_four,   [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]),
}

anscombe = pd.concat(
    [pd.DataFrame({'dataset': label, 'x': x, 'y': y}) for label, (x, y) in values.items()],
    ignore_index=True,
)
anscombe.head()

# %% [markdown]
# ## Summarise before plotting
#
# Write a Copilot prompt that asks for a grouped summary containing the mean and variance of `x` and `y`, the correlation, slope and intercept. Require one row per dataset and no chart.
#
# **Prompt summary:**
# **Expected result:**
# **What could silently go wrong:**

# %%
# TODO: calculate one summary row per dataset.
# Required columns: dataset, x_mean, y_mean, x_variance, y_variance,
# correlation, slope, intercept.
# Store the result in a DataFrame named summary.

# %%
# Verification contract: run after creating summary.
assert summary.shape == (4, 8), 'Expected one row for each dataset.'
assert set(summary['dataset']) == {'A', 'B', 'C', 'D'}
assert np.allclose(summary['x_mean'], 9.0, atol=0.01)
assert np.allclose(summary['y_mean'], 7.5, atol=0.01)
assert np.allclose(summary['correlation'], 0.816, atol=0.01)
summary

# %% [markdown]
# ## Plot before interpreting
#
# Create four small-multiple scatterplots with common axis limits. Add the fitted line to every panel. Common scales are a requirement because the task is comparison.
#
# Before asking Copilot, sketch or describe the expected output.

# %%
# TODO: draw a 2 × 2 figure using matplotlib.
# Requirements:
# - common x and y limits
# - one dataset per panel
# - points plus fitted line
# - explicit axis labels
# - no interpretation in the title
# Store the matplotlib Figure in a variable named fig.

# %% [markdown]
# ## Audit a generated interpretation
#
# Ask Copilot to write a short interpretation of the figure. Do not ask it to be persuasive. Paste the result below, then classify every claim.
#
# | Generated claim | Supported directly | Plausible but unverified | Unsupported | Contradicted |
# |---|---|---|---|---|
# | | | | | |
# | | | | | |
# | | | | | |
#
# For each supported claim, name the cell output that supports it.

# %% [markdown]
# ## Mislead, then repair
#
# Make one deliberate design change that encourages a misleading comparison—for example, inconsistent scales or a selective crop. Do not alter the underlying data.
#
# Then repair the chart and explain:
#
# - what changed visually;
# - what false impression became easier;
# - how the repair restores a fair comparison.

# %%
# TODO: create misleading_fig and repaired_fig.
# Keep the data unchanged so the effect comes only from design choices.

# %% [markdown]
# ## Provenance and exit ticket
#
# | Field | Record |
# |---|---|
# | Tool and model | |
# | Prompt summary | |
# | Output accepted | |
# | Output modified or rejected | |
# | Verification performed | |
# | What the tool missed | |
#
# Complete:
#
# - The figure invites the audience to believe …
# - The most important limitation is …
# - Before sharing it, I would verify …

# %% [markdown]
# ## AI disclosure
#
# Complete before submitting or sharing this notebook.
#
# | Question | Your answer |
# |---|---|
# | Which AI assistant(s) did you use, if any? | |
# | What did the assistant contribute (code, explanation, debugging, text)? | |
# | What did you accept, modify or reject, and why? | |
# | How did you verify the generated output (checks, tests, manual inspection)? | |
# | What limitations or unverified claims remain? | |
